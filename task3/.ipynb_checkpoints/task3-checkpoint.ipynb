# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
# %load_ext autoreload
# %autoreload 2

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print (device)
# Out:
# cuda:0

# %%
"""
数据生成
f"BOS {x} + {y} = {x+y} EOS"
f"BOS {x} - {y} = {x-y} EOS"
"""
import random
from utils import WordEmbedding, Tokenizer_Digitwise
from utils import Generate_data

train_data, train_gt, test_data, test_gt = Generate_data()
print (train_data[:2])
print (test_data[:2])
print (test_gt[:2])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[49], line 8
#       6 import random
#       7 from utils import WordEmbedding, Tokenizer_Digitwise
# ----> 8 from utils import Generate_data
#      10 train_data, train_gt, test_data, test_gt = Generate_data()
#      11 print (train_data[:2])
#
# ImportError: cannot import name 'Generate_data' from 'utils' (E:\0workspace\Sii-Task-EI\task3\utils.py)
